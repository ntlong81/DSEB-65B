# %% [markdown]
# # Lecture 1

# %% [markdown]
# $x^2+2x+3 = 0$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - item 1
# - item 2
#
# **Remark**
# <code> print("Hello") <code>

# %%
#comments
print("hello python")
# Out:
# hello python

# %%
message = "hello python"
print(message)
# Out:
# hello python

# %% [markdown]
# **2-1. Simple Message:** Assign a message to a variable, and then print that
# message.
#
# **2-2. Simple Messages:** Assign a message to a variable, and print that message.
# Then change the value of the variable to a new message, and print the new
# message.

# %%
#2-1
mess = "DSEB65B"
print(mess)
# Out:
# DSEB65B

# %%
#2-2
mess = 'Hello DSEB65B'
print(mess)
# Out:
# Hello DSEB65B

# %%
mss = '''
I dit'nt say that "this is a string"
'''  
print(mss)
# Out:
# I dit'nt say that "this is a string"

# %%
print(mss.title())
print(mss)
# Out:
# I Dit'Nt Say That "This Is A String"
#
#
# I dit'nt say that "this is a string"

# %%
dir(mss)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
first_name = "Nguyen"
last_name = "Tuan Long"
full_name = f"{first_name} {last_name}"
print(full_name)
# Out:
# Nguyen Tuan Long

# %%
first_name = "Nguyen"
last_name = "Tuan Long"
full_name = "{} {}".format(last_name,first_name)
print(full_name)
# Out:
# Tuan Long Nguyen

# %%
print(r'sdfsf\n\t\tfsfsf\tsdf')
# Out:
# sdfsf\n\t\tfsfsf\tsdf
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %%
mess1 = """
The Zen of Python, by Tim Peters

Beautiful is better than ugly.
Explicit is better than implicit.
Simple is better than complex.
Complex is better than complicated.
Flat is better than nested.
Sparse is better than dense.
Readability counts.
Special cases aren't special enough to break the rules.
Although practicality beats purity.
Errors should never pass silently.
"""

# %%
len('abc')
# Out:
# 3

# %%
len(mess1)
# Out:
# 371

# %%
print(mess1.replace('better','better'.upper()))
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is BETTER than ugly.
# Explicit is BETTER than implicit.
# Simple is BETTER than complex.
# Complex is BETTER than complicated.
# Flat is BETTER than nested.
# Sparse is BETTER than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.

# %%
#2.3
name = 'Tuan'
print(f'Hello, {name}')
# Out:
# Hello, Tuan

# %%
#2.4
print(name.upper())
print(name.title())
print(name.lower())
# Out:
# TUAN
# Tuan
# tuan

# %%
#2.5
mss = """
Albert Einstein once said, “A person who never made a
mistake never tried anything new.”
"""

print(mss)
# Out:
# Albert Einstein once said, “A person who never made a
# mistake never tried anything new.”

# %%
#2.6
famous_person = "Albert Einstein"
message = f'''{famous_person} once said, “A person who never made a
mistake never tried anything new.'''
print(message)
# Out:
# Albert Einstein once said, “A person who never made a
# mistake never tried anything new.

# %%
#2.7
name = " \tManh Cuong\n "
print(name.strip())
print(name.lstrip())
print(name.rstrip())
# Out:
# Manh Cuong
# Manh Cuong
#
#  	Manh Cuong

# %%
1 + 1 + 1 == 3
# Out:
# True

# %%
0.1 + 0.1 + 0.1 == 0.3
# Out:
# False

# %%
0.1 + 0.1 + 0.1
# Out:
# 0.30000000000000004

# %%
type(message)
# Out:
# str

# %%
n = 2
type(n)
# Out:
# int

# %%
x = 0.2
type(x)
# Out:
# float

# %%
b = n>x
b
# Out:
# True

# %%
type(b)
# Out:
# bool

# %%
int(3.4)
# Out:
# 3

# %%
int('3')
# Out:
# 3

# %%
int('sdf')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 int('sdf')
#
# ValueError: invalid literal for int() with base 10: 'sdf'

# %%
int(False)
# Out:
# 0

# %%
int(True)
# Out:
# 1

# %%
bool(1)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool('')
# Out:
# False

# %%
try:
    n  = int(input('input a number'))
    print(f"100:{n} = ",100/n)
except ZeroDivisionError:
    print('ZeroDivisionError\n','the program continues')
# Out:
# ZeroDivisionError
#  the program continues

# %%
0.1 +0.1 +0.1
# Out:
# 0.30000000000000004

# %% [markdown]
# # Lecture 2

# %% [markdown]
# ### List

# %%
digits = [1,2,3,5,3,2,0,2,7]
print(digits)
# Out:
# [1, 2, 3, 5, 3, 2, 0, 2, 7]

# %%
alist = [1,'name',True,digits]
print(alist)
# Out:
# [1, 'name', True, [1, 2, 3, 5, 3, 2, 0, 2, 7]]

# %%
digits[2]
# Out:
# 3

# %%
len(digits) # number of items in the list
# Out:
# 9

# %%
print(digits)
# Out:
# [1, 2, 3, 5, 3, 2, 0, 2, 7]

# %%
digits[0]
# Out:
# 1

# %%
digits[len(digits)-1]
# Out:
# 7

# %%
# range of index
#  positive indices: 0,1,2,....,8
# negative indices: -1,...,-9
digits[-10]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[11], line 4
#       1 # range of index
#       2 #  positive indices: 0,1,2,....,8
#       3 # negative indices: -1,...,-9
# ----> 4 digits[-10]
#
# IndexError: list index out of range

# %%
#3.1
names = ['Khoi', 'Dat', 'Minh']
print(names[0])
print(names[1])
print(names[2])
# Out:
# Khoi
# Dat
# Minh

# %%
#3.2
print(f'Hello {names[0]}')
print(f'Hello {names[1]}')
print(f'Hello {names[2]}')
# Out:
# Hello Khoi
# Hello Dat
# Hello Minh

# %%
#3.3
vehicles = ['Ferrari', 'Porsche', 'unicycle']
print(f'I would like to own a {vehicles[1]}')
print(f'But a {vehicles[0]} is fine also')
# Out:
# I would like to own a Porsche
# But a Ferrari is fine also

# %%
digits[0] = 'new_item'
digits
# Out:
# ['new_item', 2, 3, 5, 3, 2, 0, 2, 7]

# %%
digits[0] = 9999
digits
# Out:
# [9999, 2, 3, 5, 3, 2, 0, 2, 7]

# %%
digits.append(-99)
digits
# Out:
# [9999, 2, 3, 5, 3, 2, 0, 2, 7, -99]

# %%
digits += [1,2,3]

# %%
digits
# Out:
# [9999, 2, 3, 5, 3, 2, 0, 2, 7, -99, 1, 2, 3]

# %%
[1,2,3]*2
# Out:
# [1, 2, 3, 1, 2, 3]

# %%
digits.insert(5,'insert_item')

# %%
digits
# Out:
# [9999, 2, 3, 5, 3, 'insert_item', 2, 0, 2, 7, -99, 1, 2, 3]

# %%
del digits[10]
digits
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 del digits[10]
#       2 digits
#
# IndexError: list assignment index out of range

# %%
print(digits)
pop_digit = digits.pop()
print(pop_digit)
print(digits)
# Out:
# [9999, 2, 3, 5, 3, 0, 2, 7, -99, 1]
# 1
# [9999, 2, 3, 5, 3, 0, 2, 7, -99]

# %%
digits
# Out:
# [9999, 2, 3, 5, 3, 0, 2, 7, -99]

# %%
digits.remove(2)
digits
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 digits.remove(2)
#       2 digits
#
# ValueError: list.remove(x): x not in list

# %%
digits
# Out:
# [9999, 3, 5, 3, 0, 7, -99]

# %%
digits.count(3)
# Out:
# 2

# %%
digits.remove(3)
digits.remove(3)
digits
# Out:
# [9999, 5, 0, 7, -99]

# %%
words = 'methods and function'.split()
words
# Out:
# ['methods', 'and', 'function']

# %%
' '.join(words)
# Out:
# 'methods and function'

# %%
# 3.4
inviting = ["Alpha", "Beta", "Gamma"]
print(f"Dear {inviting[0]}, please join the dinner!")
print(f"Dear {inviting[1]}, please join the dinner!")
print(f"Dear {inviting[2]}, please join the dinner!")
# Out:
# Dear Alpha, please join the dinner!
# Dear Beta, please join the dinner!
# Dear Gamma, please join the dinner!

# %%
# 3.5
print(inviting[0])
inviting[0] = "Long"
print(f"Dear {inviting[0]}, please join the dinner!")
print(f"Dear {inviting[1]}, please join the dinner!")
print(f"Dear {inviting[2]}, please join the dinner!")
# Out:
# Alpha
# Dear Long, please join the dinner!
# Dear Beta, please join the dinner!
# Dear Gamma, please join the dinner!

# %%
# 3.6:
inviting.insert(0, Hung)
inviting
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 2
#       1 # 3.6:
# ----> 2 inviting.insert(0, Hung)
#       3 inviting
#
# NameError: name 'Hung' is not defined

# %%
print(inviting)
# Out:
# ['Long', 'Beta', 'Gamma']

# %%
inviting.insert(0, 'Hung')
print(inviting)
# Out:
# ['Hung']

# %%
inviting.insert(3, "Hoang")
inviting
# Out:
# ['Hung', 'Hoang']

# %%
inviting.insert(-1, "Hong")
inviting
# Out:
# ['Hung', 'Hong', 'Hoang']

# %%
inviting.append('Dung')
inviting
# Out:
# ['Hung', 'Hung', 'Long', 'Hoang', 'Beta', 'Hong', 'Gamma', 'Dung']

# %%
print(f'{inviting[0]}, please join the party')
print(f'{inviting[1]}, please join the party')
print(f'{inviting[2]}, please join the party')
print(f'{inviting[3]}, please join the party')
print(f'{inviting[4]}, please join the party')
print(f'{inviting[5]}, please join the party')
print(f'{inviting[6]}, please join the party')
# Out:
# Hung, please join the party
# Hung, please join the party
# Long, please join the party
# Hoang, please join the party
# Beta, please join the party
# Hong, please join the party
# Gamma, please join the party

# %%
#3.7:
print(f'You can invite only two people for dinner!')
popped_inviting = inviting.pop()
print(f'Sorry! {popped_inviting} can\'t invite to dinner!')
print(f'Welcome {inviting[0]} to the party!')
print(f'Welcome {inviting[1]} to the party!')
del inviting[0]
del inviting[0]
inviting
# Out:
# You can invite only two people for dinner!
# Sorry! Hoang can't invite to dinner!
# Welcome Hung to the party!
# Welcome Hong to the party!
# []

# %%
print(names)
# unspack
print(*names)
# Out:
# ['Khoi', 'Dat', 'Minh']
# Khoi Dat Minh

# %%
a,*rest    = names
print(a,rest)
# Out:
# Khoi ['Dat', 'Minh']

# %%
'list of inviting {}, {}, {}'.format(*names)
# Out:
# 'list of inviting Khoi, Dat, Minh'

# %%
digits
# Out:
# [9999, 5, 0, 7, -99]

# %%
numbers = [2,1,0,4,7]
print(sorted(numbers, reverse = True))
print(numbers)
# Out:
# [7, 4, 2, 1, 0]
# [2, 1, 0, 4, 7]

# %%
numbers = [2,1,0,4,7]
print(numbers.sort())
print(numbers)
# Out:
# None
# [0, 1, 2, 4, 7]

# %% [markdown]
# ### 3.8

# %%
places = ['Korea', 'Japan', 'Swizterland', 'China', 'Thailan']
print(places)
print(sorted(places))
print(places)
print(sorted(places, reverse = True))
print(places.sort())
print(places)
print(places.sort(reverse = True))
print(places)
# Out:
# ['Korea', 'Japan', 'Swizterland', 'China', 'Thailan']
# ['China', 'Japan', 'Korea', 'Swizterland', 'Thailan']
# ['Korea', 'Japan', 'Swizterland', 'China', 'Thailan']
# ['Thailan', 'Swizterland', 'Korea', 'Japan', 'China']
# None
# ['China', 'Japan', 'Korea', 'Swizterland', 'Thailan']
# None
# ['Thailan', 'Swizterland', 'Korea', 'Japan', 'China']

# %%
words
# Out:
# ['methods', 'and', 'function']

# %%
for w in words:
    print(w.title())
    print(w.upper(),'\n')
print(w.upper())
# Out:
# Methods
# METHODS
#
# And
# AND
#
# Function
# FUNCTION
#
# FUNCTION

# %%
for w in sorted(words):
    pass    
print(w)
# Out:
# methods

# %%
for i in [0,1,2]:
    print(words[i])
# Out:
# function
# and
# methods

# %%
list(range(2,7))#integers in [2;7)
# Out:
# [2, 3, 4, 5, 6]

# %%
letters = list("sfsfjsljaflkaflafk")
print(letters)
# Out:
# ['s', 'f', 's', 'f', 'j', 's', 'l', 'j', 'a', 'f', 'l', 'k', 'a', 'f', 'l', 'a', 'f', 'k']

# %%
letters.count('f')
# Out:
# 5

# %%
letters = list("sfsfjsljaflkaflafk")
print(letters)
letter_remove = 's'
for _ in range(1,letters.count(letter_remove)+1):
    letters.remove(letter_remove)
print(letters)
# Out:
# ['s', 'f', 's', 'f', 'j', 's', 'l', 'j', 'a', 'f', 'l', 'k', 'a', 'f', 'l', 'a', 'f', 'k']
# ['f', 'f', 'j', 'l', 'j', 'a', 'f', 'l', 'k', 'a', 'f', 'l', 'a', 'f', 'k']

# %%
list(range(2,6,2))
# Out:
# [2, 4]

# %%
squares = []
for i in range(10):
    squares.append(i**2)
print(squares)
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
#list comprehension
[i**2 for i in range(10)]
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
[f'item_{i}' for i in range(10)] #if condition
# Out:
# ['item_0',
#  'item_1',
#  'item_2',
#  'item_3',
#  'item_4',
#  'item_5',
#  'item_6',
#  'item_7',
#  'item_8',
#  'item_9']

# %%
digit_1 = [1,2,3,4,5]

# %%
max(digit_1)
# Out:
# 5

# %%
min(digits)
# Out:
# -99

# %%
sum(digit_1)
# Out:
# 15

# %%
# mean
sum(digit_1)/len(digit_1)
# Out:
# 3.0

# %%
# median
n = len(digit_1)
print(digit_1)
print(n)
# Out:
# [1, 2, 3, 4, 5]
# 5

# %% [markdown]
# # Lecture 3

# %% [markdown]
# # Lecture 4

# %% [markdown]
# # Lecture 5

# %% [markdown]
# # Lecture 6

# %% [markdown]
# # Lecture 7

# %% [markdown]
# # Lecture 8
